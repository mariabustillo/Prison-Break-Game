# %%
"""This is a game based on the series of Prison Break where the main character 
want's to help his brother to escape from prison since he was false accused of 
a murder. The game consists of three stages and the game has define functions for
each of the stages, fail, and victory. This are the following stages:
1. Trying to enter the prison
2. Making the hole for the escape. 
3. Escaping from prison
Bug/Erros """


#importing random library
import random as rd
#declaring the fail function
def fail():
#"""This is a function defined for every time the user exits or fail the game""""
    print("Game Over")
    input(prompt = "<press enter to exit>")
    
#declaring the victory function
def victory():
#""" This is a function when the user succeeds the three stages""".
    print("Congrutulation")
    input(prompt = "<press enter to continue>")
#stage 1 
def stage_1():
    #"""Function defining the first stage of the game"""
#Declaring the variable of how many chances the user have 
    chances = 2
#Declaring the variable of a list of the options.
    answer_1= ['kill your best friend and go to jail.',
               'rob a bank.',
               'hire another person to make the crime.']
#Declaring the variable of the correct answer in the list
    correct_1=('rob a bank.')
#Declaring the variable of result 
    result = ""
#Declaring the variable of error
    error = ""
#Declaring the variable exit
    exit = ""
    x = 0 

#Making a while true loop   
    while True:
        print(f"""You need to start with the plan, but the first step is to get into 
         prison with your brother. What would you to get into prison?
        
         1)kill your best friend and go to jail.
         2)rob a bank.
         3)hire another person to make the crime.""")
        
        
#Declaring the variable where the user is going to input their answer.
        choice_1 = input (prompt = f""" 
         
        Type the answer of your choice
         
        < """)
 
        #converting the choice of the user into integer
        try:
            choice_1 = int(choice_1)
#subtracting one number to the choice of the user because pyhton consider 0 as its first integer. 
            choice_1 -=1
#if python cannot convert the choice of the user integer than it should convert it to a casefold(lower case) and also eliminating the unnecesary spaces by strip(). 
        except:
            choice_1 = choice_1.casefold().strip()
#creating a for loop to iterate each item on the variable answer_1
        for item in answer_1:
#creating a if conditional statement if the user inputs their answer as an integer. 
            if type(choice_1) == int:
# If the user inputs a number greater than two (that are not in the options)then it will send him a "try again"message
                if choice_1 > 2:
                    print("""try again""")
#make a stop and asking the user to press enter
                    input(prompt="<press enter>")
#user will be directed to the first question
                    stage_1()
#if they choose the correct answer they will pass to the next stage
                elif choice_1 == answer_1.index(correct_1):
                    result="great! you are going to jail"
#the loop will break if they choose the correct answer
                    break
# if they do not choose the correct answer it will say incorrect.
                else:
                    result="Incorrect"
#if they do not input an integer than python will iterate each item in the list to consider other options as the correct answers.
            else:
# creating a conditional statement to take more options as an answer. 
                if "rob"in choice_1.lower() or "bank" in choice_1(): 
#considering all the string as a correct answer that is in the variable correct_1
                    if item in correct_1:
#if they input something that is in the variable correct_1 the result will be correct 
                        result="great! you are going to jail"
#breaking the loop
                        break
#if they input something that is not in the variable correct_1 the result will be incorrect
                    else:
                        result="Incorrect"
#try/except for when the user inputs just enter so it appears a try again messsage. 
#calling a variable to takeout the lenght of the choice.
        try:
            large = len(choice_1)
        except: 
            large = 30
#if user do not inputs anything than a try again message will appear. 
        if large == 0:
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>") 
#if they press enter they will receive a try again message.
        elif result == "":
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>") 
#if the results that is up equals to the correct answer then it will print a message of "great! your are going to jail"
        elif result=="great! you are going to jail":
            print(result)
# making a pause so the next question doesnt appear directly after the first one. 
            input(prompt="<press enter to continue>")
#sending the user to stage 2 since he pass the first stage
            stage_2()
#the loops break since he got the answer right
            break
#if he got the answer wrong then it will ask the user if he wants to continue with the game or no. 
        else:
            print(f"""result: {result}""")
#subtracting 1 chance if they got the result incorrect.
            chances -=1
#conditional statement when chances gets to zero.
            if chances == 0:
                print(f"""you have 0 chance(s) left """)
#they will fail if they reaches zero chances. 
                fail()
                break
#defining the variable exit. 
            exit = input(prompt = "enter y=yes to continue or n=no to exit")
#conditional statement for the variable exit.
            if exit.casefold().strip() == "yes" or exit.casefold().strip() == "y":
#we subtract one chance if the user got it wrong. 

#printing the messages of how many chances they have. 
                print(f"""you have {chances} chance(s) left
                    """)
#making a pause so the next question doesnt appear directly after the message of chances. 
                input(prompt = "<press enter to continue>")
#if they choose "no" they will fail and exit the game.
            else:
                fail()
                break
#defininf the stage 2 of the game.
def stage_2():
    #"""function defining the second stage of the game"""
#declaring the variable of how many chances they have. 
    chances = 2
#Declaring the variable of a list of the possible answers. 
    answer_2= ["cyclonite plus guanidine nitrate", 
               "nitroglycerin and tetryl", 
               "coppo sulfate + phosphoric acid"]
#Declaring the variable of the correct answer.
    correct_2=("coppo sulfate + phosphoric acid")
#Declaring the variable of result
    result = ""
#declaring the variable in case their is an error.
    error = ""
#Declaring the variable of exit when the player wins the game or dropoff.
    exit = ""
    x = 0 
#Making the while true loop
    while True:
        print("""You are in jail. Now you have to start with the plan. 
         You need to make the hole where you and your brother are going to 
         escape. To make the hole you need first to destroy the cement 
         creating a bomb. What elements will you use to make the bomb?
         
                    1) cyclonite plus guanidine nitrate 
                    2) nitroglycerin and tetryl" 
                    3) coppo sulfate + phosphoric acid""")
        
#Declaring the variable where the user is going to input their answer.
        choice_2 = input(prompt="""
         
         Type your Answer
         
        > """)
#converting the choice of the user into integer.
        try:
            choice_2 = int(choice_2)
#resting one number to the choice of the user since python consider the index number starting from 0.
            choice_2 -=1
#if python cannot convert the answer to integer, then its going to try to convert it to casefold(lower case) and eliminates any space.
        except:
            choice_2 = choice_2.casefold().strip()
#creating a for loop for the answer of stage two 
        for item in answer_2:
#conditional statement for when the choice of the user is an integer.
            if type(choice_2) == int:
#stating that if they choose an answer greater than the answer in index two is incorrect
                if choice_2 > 2:
#printing a message of try again if the choice of the user is greater than two. 
                    print("""try it again""")
#making a pause for the user to press enter. 
                    input(prompt="<press enter>")
#if they input a choice that is not in the indexes of the list of answer than they will restart the stage 2 
                    stage_2()
#if the choice does equal to the correct answer than the result will be a congrats message
                elif choice_2 == answer_2.index(correct_2):
                    result="Congrats! The hole is made, let's escape"
#breaking the loop since the answer was correct. 
                    break
#if the answer wasn't equal to the correct answer than the result will be incorrect.
                else:
                    result="Incorrect"
#if the choice is not equal to the integer. Python will consider the words in that are in the index of the correct answer.
            else:
# creating a conditional statement to take more options as an answer.
                if "coppo"in choice_2.lower() or "sulfate" in choice_2.lower() or "phosphoric"in choice_2.lower() or "acid" in choice_2.lower(): 
                    if item in correct_2:
                        result="Congrats! The hole is made, let's escape"
#breaking the loop of for.
                        break
# if the input is not in the correct answer the result will be incorrect. 
                    else:
                        result="Incorrect"
#try/except for when the user inputs just enter so it appears a try again messsage. 
#calling a variable to takeout the lenght of the choice.
        try:
            large = len(choice_2)
        except: 
            large = 30
#if do not puts anything than a try again message will appear. 
        if large == 0:
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>") 
#if they press enter they will receive a try again message. 
        elif result == "":
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>")  
#if the result is equal when the you get the correct answer than it'll print a congrats message. 
        elif result=="Congrats! The hole is made, let's escape":
#printing the result.
            print(result)
#making a pause for the user.
            input(prompt = "<press enter to continue>")
#if the result is right than they will pass to stage 3
            stage_3()
#the loop is break.
            break
#the other option is to get the answer wrong.
        else:
            print(f"""result: {result}""")
#resting 1 chance if they got the result incorrect.
            chances -=1
#conditional statement if chances is equal to zero. 
            if chances == 0:
                print(f"""you have 0 chance(s) left """)
#fail variable is being called if they reaches zero.
                fail()
                break
            exit = input(prompt = "enter y=yes to continue or n=no to exit")
#conditional statement for the variable exit.
            if exit.casefold().strip() == "yes" or exit.casefold().strip() == "y":

#printing the messages of how many chances they have. 
                print(f"""you have {chances} chance(s) left
                    """)
#making a pause so the next question doesnt appear directly after the message of chances. 
                input(prompt = "<press enter to continue>")
#if they choose "no" they will fail and exit the game.

            else:
                fail()
                break
#stage 3 function defining.               
def stage_3():
    #"""function defining the third stage of the game"""
#defininf a random variable. 
    randomevent = ""
#defining the variable chances of the user. 
    chances = 2
#defining the list of possible answers of the question in stage 3. 
    answer_3= ["use a hacksaw", "attach a rope from the window to the elevator.", "pull the strand with all your strength."]
#defining the variable correct answer.
    correct_3=("attach a rope from the window to the elevator.")
#defining the variable result.
    result = ""
#defining the variable error. 
    error = ""
#defining the exit variable. 
    exit = ""
    x = 0 
#making the while true loop.
    while True:
        print(""" Oh, Snap! The police found the hole, and you couldn't escape but, 
         you have to escape tonight because they suspect you. Right now you 
         and your brother are in the prison clinic.
         You thought of escaping from the clinic window attaching a rope from 
         the window to the exterior wall of the prison that goes directly to 
         the street. First, you need to break the steel window and then jump 
         to the rope and escape. How would you break the window?
                  
                   1) use a hacksaw, 
                   2) attach a rope from the window to the elevator.,
                   3) pull the strand with all your strength.""")

#variable for the user to input the answer.
        choice_3 = input(prompt="""
         
         Type your Answer
         
        > """)
#trying to convert the choice of the user to integer.
        try:
            choice_3 = int(choice_3)
#resting one number to the choice of the user since python start from 0.
            choice_3 -=1
#if the choice cannot be converted to an integer than python will try to convert it to a casefold(lowercase) and eliminates any space.
        except:
            choice_3 = choice_3.casefold().strip()
#if at the end the choice is an integer...
#making a for loop so it can take all the possible answer the user inputs.
        for item in answer_3:

            if type(choice_3) == int:
#if the choice is greater than the index two then..
                if choice_3 > 2:
#printing a message to try it again.
                    print("""try again""")
#making a pause for a better experience of the user. 
                    input(prompt="<press enter>")
#they will restart the stage 3
                    stage_3()
#if the choice is equal to the index of the correct answer in the list then the result will be congrats..
                elif choice_3 == answer_3.index(correct_3):
                    result="congrats!, let's see if the police saw you"
#breaking the for loop.
                    break
#the result will equal to "incorrect" if they do not answer correctly.
                else:
                    result="incorrect"
#if the choice is not an integer than..
            else:
# creating a conditional statement to take more options as an answer.
                if "attach" in choice_3.lower() or "rope" in choice_3.lower() or "window"in choice_3.lower() or "elevator" in choice_3.lower():
#making a conditional statement if the choice is equal to the correct answer.
#the result will be correct.
                    if item in correct_3:
                        result="congrats!, let's see if the police saw you"
#breaking the loop.
                        break
# the result will be incorrect.
                    else:
                        result="incorrect"
#try/except for when the user inputs just enter so it appears a try again messsage. 
#calling a variable to takeout the lenght of the choice.
        try:
            large = len(choice_3)
        except: 
            large = 30
#if do not puts anything than a try again message will appear.             
        if large == 0:
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>") 
#if they press enter they will receive a try again message. 
        elif result == "":
            print("""try it again because I didn't understand what you mean""")
            input(prompt="<press enter>") 
#if the results equals to "congrats you scape from jail
        elif result == "congrats!, let's see if the police saw you":
#printing the result.
            print(result)
#making a pause for the user. 
            input(prompt = "<press enter to continue>")
#defining a random variable to the function random_event.
            randomevent = random_event()
#if the randomevent equals to the first option of the random function it will print "police saw you".
            if randomevent == "police saw you":
                print("police saw you")
#the fail function will appear and they lost the game.
                fail()
#if the variable randomevent is eqaul to the second option of the random function than they'll win
            else:
                print("You win")
#breaking the loop
                break
            break
#if they got the answer wrong then they will decide if they want to continue or not. 
        else:
            print(f"""result: {result}""")
#subtracting 1 chance for every time a result is incorrect.
            chances -=1
#conditional statement for when the chances are zero.
            if chances == 0:
                print(f"""you have 0 chance(s) left """)
#calling the fail function when they have 0 chances.
                fail()
                break
            exit = input(prompt = "enter y=yes to continue or n=no to exit")
#conditional statement for the variable exit.
            if exit.casefold().strip() == "yes" or exit.casefold().strip() == "y":
#we subtract one chance if the user got it wrong. 

#printing the messages of how many chances they have. 
                print(f"""you have {chances} chance(s) left
                    """)
#making a pause so the next question doesnt appear directly after the message of chances. 
                input(prompt = "<press enter to continue>")
#if they choose "no" they will fail and exit the game.
            else:
                fail()
                break
#defining a random function to know if they could escape or not from the prison.
def random_event():
    #"""function randomizing the event when they answer the correct answer of stage three but want to know if they got caught by the police"""

    random_event = ["police saw you", "escape"]
#creating the variable randchose to creat the indexes. 
    randchose = rd.randint(0,1)
    #print(randchose)
    chosenrand = random_event[randchose]
    #print(chosenrand)
    return chosenrand

#introduction 
name=input(prompt="what is your name?\n")

print(f"""Hello {name.capitalize()}, welcome to the game where doing crimes will make you 
a hero! This is a game based on the series Prison Break, you are Michael 
Scofield and your brother was wrongly accused of killing the vice president's 
daughter. Now he is in prison and sentenced to death. The only way he can 
survive is by escaping from prison and you are the one who will help him 
escape. You have been planning the escape for 3 months now. 
Let's see if you can save the life of your brother!!""")

input(prompt = "< press enter to continue>")
stage_1()
# Out:
# what is your name?
# maria
# Hello Maria, welcome to the game where doing crimes will make you
# a hero! This is a game based on the series Prison Break, you are Michael
# Scofield and your brother was wrongly accused of killing the vice president's
# daughter. Now he is in prison and sentenced to death. The only way he can
# survive is by escaping from prison and you are the one who will help him
# escape. You have been planning the escape for 3 months now.
# Let's see if you can save the life of your brother!!
# < press enter to continue>
# You need to start with the plan, but the first step is to get into
#          prison with your brother. What would you to get into prison?
#
#          1)kill your best friend and go to jail.
#          2)rob a bank.
#          3)hire another person to make the crime.
#
#
#         Type the answer of your choice
#
#         < rob a
# great! you are going to jail
# <press enter to continue>
# You are in jail. Now you have to start with the plan.
# ...
